# %% [markdown]
# # Titanic Kaggle Submission - Owen Campbell
# ## Predicting Survival on the Titantic
#
# This notebook follows a structured approach to loading, cleaning, analyzing, training, and evaluating a machine-learning model for the Titanic dataset.

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Import project scripts
import scripts.load as load # load.py
import scripts.eda as eda # eda.py

# %% [markdown]
# ## Load and Inspect Data
# This section loads the Titanic dataset from CSV files and summarizes its structure, statistics, and missing values.

# %%
# Load train and test datasets
train_df, test_df = load.load_data()

# Inspect train dataset
load.inspect_data(train_df, "Train Data")

# Inspect test dataset
load.inspect_data(test_df, "Test Data")
# Out:
#  Inspecting Train Data...
#
# 🔹 First 5 rows:
#
#    PassengerId  Survived  Pclass                                                 Name     Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0            1         0       3                              Braund, Mr. Owen Harris    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1            2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2            3         1       3                               Heikkinen, Miss. Laina  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3            4         1       1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0            113803  53.1000  C123        S
# 4            5         0       3                             Allen, Mr. William Henry    male  35.0      0      0            373450   8.0500   NaN        S
#
# ...

# %% [markdown]
# ## Perform Exploratory Data Analysis
# This section plots the charts and maps to show data distribution and survival correlations

# %%
# Import plot functions from eda.py, use the load_data function to load the data, plot the charts and maps using train data 
from scripts.eda import distribution_data, plot_categorical_survival, plot_survival_by_age, plot_survival_correlation
train_df, test_df = load.load_data()
distribution_data(train_df)
plot_categorical_survival(train_df)
plot_survival_by_age(train_df)
plot_survival_correlation(train_df)

# %% [markdown]
# ## Key Takeaways from Exploratory Data Analysis
#
# - **Survival Rate**: Only **38.4%** of passengers survived, while **61.6%** did not.
# - **Age Distribution**: The majority of passengers were between **20 and 40 years old**, with survival rates varying across age groups.
# - **Class and Survival**: **First-class passengers had the highest survival rates**, while **third-class passengers had the lowest**.
# - **Gender and Survival**: **Females had a significantly higher survival rate** compared to males.
# - **Embarkation and Survival**: Passengers who embarked from **Cherbourg (C) had a higher survival rate** compared to those from Queenstown (Q) or Southampton (S).
# - **Fare and Survival**: **Higher ticket fares correlated positively with survival**, suggesting wealthier passengers had better chances.
# - **Family Size Impact**: Having **parents/children aboard increased survival chances**, while **more siblings/spouses decreased survival**.
